# %% [markdown]
# #### This one cleans the main source dataset

# %%
import pandas as pd
import numpy as np
from rake_nltk import Rake
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %% [markdown]
# ##### We need to concat most of the separate files into one. Or at least the relevant ones

# %%
movie_metadata = pd.read_csv("datasets/movies_metadata.csv")
links_df = pd.read_csv("datasets/links.csv")
keywords_df = pd.read_csv("datasets/keywords.csv")
credits_df = pd.read_csv("datasets/credits.csv")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_37756\3605348483.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   movie_metadata = pd.read_csv("source/movies_metadata.csv")

# %%
movie_metadata['id'] = pd.to_numeric(movie_metadata['id'], errors='coerce')
movie_metadata = movie_metadata[movie_metadata['id'].notna()].astype({'id': int})

# %% [markdown]
# #### Clean up all the irrelevant columns

# %%
links_df.rename(columns={'movieId':'id'},inplace=True)

# %%
full_df = movie_metadata.merge(keywords_df, on='id')
full_df = full_df.merge(credits_df[['cast', 'crew', 'id']], on='id')
full_df = full_df.merge(links_df, on='id')

# %%
full_df
# Out:
#       adult                              belongs_to_collection    budget  \
# 0     False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1     False                                                NaN  65000000
# 2     False                                                NaN  60000000
# 3     False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 4     False                                                NaN  98000000
# ...     ...                                                ...       ...
# 7762  False                                                NaN         0
# 7763  False                                                NaN         0
# 7764  False                                                NaN         0
# 7765  False                                                NaN         0
# 7766  False                                                NaN         0
#
#                                                  genres  \
# 0     [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1     [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2     [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 3     [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 4     [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# ...                                                 ...
# 7762  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 7763  [{'id': 10402, 'name': 'Music'}, {'id': 35, 'n...
# 7764  [{'id': 28, 'name': 'Action'}, {'id': 9648, 'n...
# 7765  [{'id': 14, 'name': 'Fantasy'}, {'id': 28, 'na...
# 7766                      [{'id': 18, 'name': 'Drama'}]
#
#                                           homepage      id    imdb_id  \
# 0             http://toystory.disney.com/toy-story     862  tt0114709
# 1                                              NaN    8844  tt0113497
# 2                                              NaN     949  tt0113277
# 3     http://www.mgm.com/view/movie/757/Goldeneye/     710  tt0113189
# 4                                              NaN    1408  tt0112760
# ...                                            ...     ...        ...
# 7762                                           NaN   98604  tt2147597
# 7763                                           NaN    5589  tt0232750
# 7764                                           NaN   45527  tt1331329
# 7765                                           NaN   49280  tt0135453
# 7766                                           NaN  111109  tt2028550
#
#      original_language           original_title  \
# 0                   en                Toy Story
# 1                   en                  Jumanji
# 2                   en                     Heat
# 3                   en                GoldenEye
# 4                   en         Cutthroat Island
# ...                ...                      ...
# 7762                ru                 Zolushka
# 7763                cs  Šíleně smutná princezna
# 7764                en          The Final Storm
# 7765                fr        L'Homme orchestre
# 7766                tl      Siglo ng Pagluluwal
#
#                                                overview  ...  \
# 0     Led by Woody, Andy's toys live happily in his ...  ...
# 1     When siblings Judy and Peter discover an encha...  ...
# 2     Obsessive master thief, Neil McCauley leads a ...  ...
# 3     James Bond must unmask the mysterious head of ...  ...
# 4     Morgan Adams and her slave, William Shaw, are ...  ...
# ...                                                 ...  ...
# 7762  Masha Krapivina - is yet beautiful, and not th...  ...
# 7763                                 No overview found.  ...
# 7764  A stranger named Silas flees from a devastatin...  ...
# 7765  A band-leader has arranged seven chairs for th...  ...
# 7766  An artist struggles to finish his work while a...  ...
#
#                                                 tagline  \
# 0                                                   NaN
# 1             Roll the dice and unleash the excitement!
# 2                              A Los Angeles Crime Saga
# 3                  No limits. No fears. No substitutes.
# 4     The Course Has Been Set. There Is No Turning B...
# ...                                                 ...
# 7762                                                NaN
# 7763                                                NaN
# 7764                                     Action, Horror
# 7765                                                NaN
# 7766                                                NaN
#
#                         title  video vote_average vote_count  \
# 0                   Toy Story  False          7.7     5415.0
# 1                     Jumanji  False          6.9     2413.0
# 2                        Heat  False          7.7     1886.0
# 3                   GoldenEye  False          6.6     1194.0
# 4            Cutthroat Island  False          5.7      137.0
# ...                       ...    ...          ...        ...
# 7762               Cinderella  False          4.6        6.0
# 7763  Šíleně smutná princezna  False          6.1        4.0
# 7764          The Final Storm  False          3.7       11.0
# 7765         The One-Man Band  False          6.5       22.0
# 7766      Century of Birthing  False          9.0        3.0
#
#                                                keywords  \
# 0     [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1     [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2     [{'id': 642, 'name': 'robbery'}, {'id': 703, '...
# 3     [{'id': 701, 'name': 'cuba'}, {'id': 769, 'nam...
# 4     [{'id': 911, 'name': 'exotic island'}, {'id': ...
# ...                                                 ...
# 7762                                                 []
# 7763  [{'id': 3205, 'name': 'fairy tale'}, {'id': 13...
# 7764                                                 []
# 7765                                                 []
# 7766  [{'id': 2679, 'name': 'artist'}, {'id': 14531,...
#
#                                                    cast  \
# 0     [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1     [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2     [{'cast_id': 25, 'character': 'Lt. Vincent Han...
# 3     [{'cast_id': 1, 'character': 'James Bond', 'cr...
# 4     [{'cast_id': 1, 'character': 'Morgan Adams', '...
# ...                                                 ...
# 7762  [{'cast_id': 1001, 'character': 'Masha', 'cred...
# 7763  [{'cast_id': 12, 'character': 'princezna Helen...
# 7764  [{'cast_id': 1, 'character': 'Gillian Grady', ...
# 7765  [{'cast_id': 3, 'character': 'All the members ...
# 7766  [{'cast_id': 1002, 'character': 'Sister Angela...
#
#                                                    crew   imdbId   tmdbId
# 0     [{'credit_id': '52fe4284c3a36847f8024f49', 'de...   116985  88224.0
# 1     [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...    78763  42164.0
# 2     [{'credit_id': '52fe4292c3a36847f802916d', 'de...    48028    220.0
# 3     [{'credit_id': '52fe426ec3a36847f801e14b', 'de...   115851  23449.0
# 4     [{'credit_id': '52fe42f4c3a36847f802f69f', 'de...   104691   9361.0
# ...                                                 ...      ...      ...
# 7762  [{'credit_id': '52fe4a1c9251416c750de11b', 'de...  1798188  83389.0
# 7763  [{'credit_id': '52fe440fc3a36847f807ffa3', 'de...   107212  33506.0
# 7764  [{'credit_id': '52fe46c7c3a36847f81119a1', 'de...   360016  14167.0
# 7765  [{'credit_id': '52fe478dc3a36847f813bd6b', 'de...   308055  10741.0
# 7766  [{'credit_id': '52fe4af1c3a36847f81e9b15', 'de...    70363  42472.0
#
# [7767 rows x 29 columns]

# %%
def convert_dict_list_to_list(column):
    
    if isinstance(column, str) and isinstance(eval(column), list):
        evaluated_list = eval(column)
    else:
        return np.nan #Will be removed

    column_list_item = []
    for dict_item in evaluated_list:
        column_list_item.append(dict_item['name'])
    return column_list_item

# %%
#Tagline has NAN
#Won't be prompting original_language
full_df.drop(['adult', 'belongs_to_collection', 'homepage', 'tagline', 'video', 'poster_path'], axis=1, inplace=True)

# %%
full_df['genres'] = full_df['genres'].apply(lambda x : convert_dict_list_to_list(x))
full_df['production_countries'] = full_df['production_countries'].apply(lambda x : convert_dict_list_to_list(x))
full_df['production_companies'] = full_df['production_companies'].apply(lambda x : convert_dict_list_to_list(x))
full_df['spoken_languages'] = full_df['spoken_languages'].apply(lambda x : convert_dict_list_to_list(x))
full_df['keywords'] = full_df['keywords'].apply(lambda x : convert_dict_list_to_list(x))
full_df['cast'] = full_df['cast'].apply(lambda x : convert_dict_list_to_list(x))
full_df['crew'] = full_df['crew'].apply(lambda x : convert_dict_list_to_list(x))

# %% [markdown]
# #### Remove rows that are not in English, we focus solely on English movies

# %%
full_df = full_df[full_df['original_language'] == 'en']

# %% [markdown]
# #### Get important keywords from overview and merge with keywords column and remove duplicates

# %%
def get_keywords_from_overview(overview):
    if pd.isnull(overview) == False:
        r = Rake()
        r.extract_keywords_from_text(overview)
        key_words_dict_scores = r.get_word_degrees()

        return list(key_words_dict_scores.keys())
    else:
        return []

# %%
full_df['overview'] = full_df['overview'].astype("string")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_37756\510849226.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_df['overview'] = full_df['overview'].astype("string")

# %%
full_df['overview'].isna
# Out:
# <bound method Series.isna of 0       Led by Woody, Andy's toys live happily in his ...
# 1       When siblings Judy and Peter discover an encha...
# 2       Obsessive master thief, Neil McCauley leads a ...
# 3       James Bond must unmask the mysterious head of ...
# 4       Morgan Adams and her slave, William Shaw, are ...
#                               ...
# 7754    A deformed tormented girl drowns herself after...
# 7755    A group of fashion models disturb the tomb of ...
# 7756    A less-than-qualified and far-from-perfect pri...
# 7758          An abstract animation from Walter Ruttmann.
# 7764    A stranger named Silas flees from a devastatin...
# Name: overview, Length: 5533, dtype: string>

# %%
full_df.dtypes
# Out:
# budget                   object
# genres                   object
# id                        int32
# imdb_id                  object
# original_language        object
# original_title           object
# overview                 string
# popularity               object
# production_companies     object
# production_countries     object
# release_date             object
# revenue                 float64
# runtime                 float64
# spoken_languages         object
# status                   object
# title                    object
# vote_average            float64
# vote_count              float64
# keywords                 object
# cast                     object
# crew                     object
# imdbId                    int64
# tmdbId                  float64
# dtype: object

# %%
full_df
# Out:
#         budget                               genres      id    imdb_id  \
# 0     30000000          [Animation, Comedy, Family]     862  tt0114709
# 1     65000000         [Adventure, Fantasy, Family]    8844  tt0113497
# 2     60000000     [Action, Crime, Drama, Thriller]     949  tt0113277
# 3     58000000        [Adventure, Action, Thriller]     710  tt0113189
# 4     98000000                  [Action, Adventure]    1408  tt0112760
# ...        ...                                  ...     ...        ...
# 7754         0            [Horror, Science Fiction]    3104  tt0061683
# 7755    500000                             [Horror]   40467  tt0082237
# 7756         0                             [Comedy]   79927  tt0102691
# 7758         0                          [Animation]  175457  tt0403386
# 7764         0  [Action, Mystery, Thriller, Horror]   45527  tt1331329
#
#      original_language              original_title  \
# 0                   en                   Toy Story
# 1                   en                     Jumanji
# 2                   en                        Heat
# 3                   en                   GoldenEye
# 4                   en            Cutthroat Island
# ...                ...                         ...
# 7754                en  Frankenstein Created Woman
# 7755                en           Dawn of the Mummy
# 7756                en           The Pope Must Die
# 7758                en                     Opus II
# 7764                en             The Final Storm
#
#                                                overview popularity  \
# 0     Led by Woody, Andy's toys live happily in his ...  21.946943
# 1     When siblings Judy and Peter discover an encha...  17.015539
# 2     Obsessive master thief, Neil McCauley leads a ...  17.924927
# 3     James Bond must unmask the mysterious head of ...  14.686036
# 4     Morgan Adams and her slave, William Shaw, are ...   7.284477
# ...                                                 ...        ...
# 7754  A deformed tormented girl drowns herself after...   2.302582
# 7755  A group of fashion models disturb the tomb of ...   0.283443
# 7756  A less-than-qualified and far-from-perfect pri...   9.015632
# 7758        An abstract animation from Walter Ruttmann.   0.177238
# 7764  A stranger named Silas flees from a devastatin...   1.270832
#
#                                    production_companies  \
# 0                             [Pixar Animation Studios]
# 1     [TriStar Pictures, Teitler Film, Interscope Co...
# 2     [Regency Enterprises, Forward Pass, Warner Bros.]
# 3                     [United Artists, Eon Productions]
# 4     [Le Studio Canal+, Laurence Mark Productions, ...
# ...                                                 ...
# 7754                          [Hammer Film Productions]
# 7755                                     [Harmony Gold]
# 7756   [Channel Four Films, British Screen Productions]
# 7758                                                 []
# 7764  [Boll Kino Beteiligungs GmbH & Co. KG, Brightl...
#
#                                    production_countries  ...  \
# 0                            [United States of America]  ...
# 1                            [United States of America]  ...
# 2                            [United States of America]  ...
# 3            [United Kingdom, United States of America]  ...
# 4     [France, Germany, Italy, United States of Amer...  ...
# ...                                                 ...  ...
# 7754                                   [United Kingdom]  ...
# 7755           [Egypt, Italy, United States of America]  ...
# 7756                                   [United Kingdom]  ...
# 7758                                          [Germany]  ...
# 7764                                  [Canada, Germany]  ...
#
#                  spoken_languages    status                       title  \
# 0                       [English]  Released                   Toy Story
# 1             [English, Français]  Released                     Jumanji
# 2              [English, Español]  Released                        Heat
# 3     [English, Pусский, Español]  Released                   GoldenEye
# 4                [English, Latin]  Released            Cutthroat Island
# ...                           ...       ...                         ...
# 7754                    [English]  Released  Frankenstein Created Woman
# 7755                    [English]  Released           Dawn of the Mummy
# 7756                    [English]  Released           The Pope Must Die
# 7758                           []  Released                     Opus II
# 7764                    [English]  Released             The Final Storm
#
#      vote_average vote_count  \
# 0             7.7     5415.0
# 1             6.9     2413.0
# 2             7.7     1886.0
# 3             6.6     1194.0
# 4             5.7      137.0
# ...           ...        ...
# 7754          5.9       33.0
# 7755          3.6        8.0
# 7756          4.2       12.0
# 7758          6.7        5.0
# 7764          3.7       11.0
#
#                                                keywords  \
# 0     [jealousy, toy, boy, friendship, friends, riva...
# 1     [board game, disappearance, based on children'...
# 2     [robbery, detective, bank, obsession, chase, s...
# 3     [cuba, falsely accused, secret identity, compu...
# 4     [exotic island, treasure, map, ship, scalp, pi...
# ...                                                 ...
# 7754                      [frankenstein, hammer horror]
# 7755                 [mummy, gore, curse, zombie, tomb]
# 7756        [vatican, pope, priest, alternative comedy]
# 7758                                                 []
# 7764                                                 []
#
#                                                    cast  \
# 0     [Tom Hanks, Tim Allen, Don Rickles, Jim Varney...
# 1     [Robin Williams, Jonathan Hyde, Kirsten Dunst,...
# 2     [Al Pacino, Robert De Niro, Val Kilmer, Jon Vo...
# 3     [Pierce Brosnan, Sean Bean, Izabella Scorupco,...
# 4     [Geena Davis, Matthew Modine, Frank Langella, ...
# ...                                                 ...
# 7754  [Peter Cushing, Susan Denberg, Thorley Walters...
# 7755  [Brenda Siemer Scheider, Barry Sattels, George...
# 7756  [Robbie Coltrane, Beverly D'Angelo, Alex Rocco...
# 7758                                                 []
# 7764  [Lauren Holly, Luke Perry, Steve Bacic, Cole H...
#
#                                                    crew   imdbId    tmdbId
# 0     [John Lasseter, Joss Whedon, Andrew Stanton, J...   116985   88224.0
# 1     [Larry J. Franco, Jonathan Hensleigh, James Ho...    78763   42164.0
# 2     [Michael Mann, Michael Mann, Art Linson, Micha...    48028     220.0
# 3     [Martin Campbell, Ian Fleming, Jeffrey Caine, ...   115851   23449.0
# 4     [Peter Levy, Maggie Gray, Norman Garwood, Mari...   104691    9361.0
# ...                                                 ...      ...       ...
# 7754  [Terence Fisher, Anthony Hinds, Anthony Nelson...    95631    9013.0
# 7755  [Frank Agrama, Daria Price, Ronald Dobrin, Fra...    58155   28667.0
# 7756  [Sandy Powell, Peter Richardson, Peter Richard...  1087890   15952.0
# 7758                                  [Walter Ruttmann]  6070530  415892.0
# 7764  [Uwe Boll, Uwe Boll, Mathias Neumann, Dan Clar...   360016   14167.0
#
# [5533 rows x 23 columns]

# %%
full_df['overview'] = full_df['overview'].apply(lambda x : get_keywords_from_overview(x))
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_37756\1389888076.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_df['overview'] = full_df['overview'].apply(lambda x : get_keywords_from_overview(x))

# %% [markdown]
# #### Actual Processing of files

# %%
def remove_stopwords(text):
    stop_words = set(stopwords.words('english'))
    list_of_text = text

    if (len(list_of_text) == 0):
        return []

    filtered_sentence = []

    for w in list_of_text:
        lower_text = w.lower()
        if lower_text not in stop_words:
            filtered_sentence.append(lower_text)

    return filtered_sentence

# %%
full_df['overview'] = full_df['overview'].apply(lambda x : remove_stopwords(x))
full_df['genres'] = full_df['genres'].astype("string")
full_df['overview'] = full_df['overview'].astype("string")
full_df['production_companies'] = full_df['production_companies'].astype("string")
full_df['production_countries'] = full_df['production_countries'].astype("string")
full_df['keywords'] = full_df['keywords'].astype("string")
full_df['cast'] = full_df['cast'].astype("string")
full_df['crew'] = full_df['crew'].astype("string")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_37756\3522312212.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_df['overview'] = full_df['overview'].apply(lambda x : remove_stopwords(x))
# C:\Users\User\AppData\Local\Temp\ipykernel_37756\3522312212.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_df['genres'] = full_df['genres'].astype("string")
# C:\Users\User\AppData\Local\Temp\ipykernel_37756\3522312212.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_df['overview'] = full_df['overview'].astype("string")
# C:\Users\User\AppData\Local\Temp\ipykernel_37756\3522312212.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_df['production_companies'] = full_df['production_companies'].astype("string")
# C:\Users\User\AppData\Local\Temp\ipykernel_37756\3522312212.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_df['production_countries'] = full_df['production_countries'].astype("string")
# C:\Users\User\AppData\Local\Temp\ipykernel_37756\3522312212.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_df['keywords'] = full_df['keywords'].astype("string")
# C:\Users\User\AppData\Local\Temp\ipykernel_37756\3522312212.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_df['cast'] = full_df['cast'].astype("string")
# C:\Users\User\AppData\Local\Temp\ipykernel_37756\3522312212.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_df['crew'] = full_df['crew'].astype("string")

# %%
def combine_all_into_bow(row):
    # genre_row = row['genres']
    # overview_row = row['overview']
    # production_companies_row = row['production_companies']
    # production_countries_row = row['production_countries']
    # keywords_row = row['keywords']
    # cast_row = row['cast']
    # crew_row = row['crew']
    # title_row = row['title']

    genre_row = eval(row['genres'])
    overview_row = eval(row['overview'])
    production_companies_row = eval(row['production_companies'])
    production_countries_row = eval(row['production_countries'])
    keywords_row = eval(row['keywords'])
    cast_row = eval(row['cast'])
    crew_row = eval(row['crew'])
    title_row = row['title']

    #Note: Overview keywords will be merged with keywords row to ensure no duplicates.
    overview_keyword_merge = []
    overview_keyword_merge.extend(overview_row)
    overview_keyword_merge.extend(keywords_row)
    
    keywords_no_dup = list(set(overview_keyword_merge))

    #Lowercase all rows that has them
    l_genre_row = map(lambda x : x.lower(), genre_row)
    l_production_companies_row = map(lambda x : x.lower(), production_companies_row)
    l_production_countries_row = map(lambda x : x.lower(), production_countries_row)
    l_cast_row = map(lambda x : x.lower(), cast_row)
    l_crew_row = map(lambda x : x.lower(), crew_row)

    bow_merge = []

    bow_merge.extend(keywords_no_dup)
    bow_merge.extend(l_genre_row)
    bow_merge.extend(l_production_companies_row)
    bow_merge.extend(l_production_countries_row)
    bow_merge.extend(l_cast_row)
    bow_merge.extend(l_crew_row)
    bow_merge.append(title_row.lower())

    return ' '.join(bow_merge)

# %%
full_df['bag_of_words'] = full_df.apply(lambda x : combine_all_into_bow(x), axis=1)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_37756\2023492153.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_df['bag_of_words'] = full_df.apply(lambda x : combine_all_into_bow(x), axis=1)

# %%
final_df = full_df[["title", "vote_average", "release_date", "popularity" ,"bag_of_words", "imdbId", "tmdbId"]]

# %%
final_df
# Out:
#                            title  vote_average release_date popularity  \
# 0                      Toy Story           7.7   1995-10-30  21.946943
# 1                        Jumanji           6.9   1995-12-15  17.015539
# 2                           Heat           7.7   1995-12-15  17.924927
# 3                      GoldenEye           6.6   1995-11-16  14.686036
# 4               Cutthroat Island           5.7   1995-12-22   7.284477
# ...                          ...           ...          ...        ...
# 7754  Frankenstein Created Woman           5.9   1967-03-15   2.302582
# 7755           Dawn of the Mummy           3.6   1981-12-11   0.283443
# 7756           The Pope Must Die           4.2   1991-06-21   9.015632
# 7758                     Opus II           6.7   1921-12-31   0.177238
# 7764             The Final Storm           3.7   2010-01-01   1.270832
#
#                                            bag_of_words   imdbId    tmdbId
# 0     jealousy woody toy afraid separate differences...   116985   88224.0
# 1     recluse giant insect discover magical inside t...    78763   42164.0
# 2     detective bank respects unstable notch robbery...    48028     220.0
# 3     unmask goldeneye prevent secret identity must ...   115851   23449.0
# 4     shaw must three skeptical exotic island raids ...   104691    9361.0
# ...                                                 ...      ...       ...
# 7754  hammer horror carries body responsible life to...    95631    9013.0
# 7755  craving group tomb revive curse years flesh sl...    58155   28667.0
# 7756  far vatican must priest named new qualified ol...  1087890   15952.0
# 7758  walter abstract animation ruttmann animation g...  6070530  415892.0
# 7764  dangerous three son named devastating silas re...   360016   14167.0
#
# [5533 rows x 7 columns]

# %%
## Remove duplicated titles if any
final_df = final_df.drop_duplicates(subset="title")

# %%
final_df
# Out:
#                            title  vote_average release_date popularity  \
# 0                      Toy Story           7.7   1995-10-30  21.946943
# 1                        Jumanji           6.9   1995-12-15  17.015539
# 2                           Heat           7.7   1995-12-15  17.924927
# 3                      GoldenEye           6.6   1995-11-16  14.686036
# 4               Cutthroat Island           5.7   1995-12-22   7.284477
# ...                          ...           ...          ...        ...
# 7754  Frankenstein Created Woman           5.9   1967-03-15   2.302582
# 7755           Dawn of the Mummy           3.6   1981-12-11   0.283443
# 7756           The Pope Must Die           4.2   1991-06-21   9.015632
# 7758                     Opus II           6.7   1921-12-31   0.177238
# 7764             The Final Storm           3.7   2010-01-01   1.270832
#
#                                            bag_of_words   imdbId    tmdbId
# 0     jealousy woody toy afraid separate differences...   116985   88224.0
# 1     recluse giant insect discover magical inside t...    78763   42164.0
# 2     detective bank respects unstable notch robbery...    48028     220.0
# 3     unmask goldeneye prevent secret identity must ...   115851   23449.0
# 4     shaw must three skeptical exotic island raids ...   104691    9361.0
# ...                                                 ...      ...       ...
# 7754  hammer horror carries body responsible life to...    95631    9013.0
# 7755  craving group tomb revive curse years flesh sl...    58155   28667.0
# 7756  far vatican must priest named new qualified ol...  1087890   15952.0
# 7758  walter abstract animation ruttmann animation g...  6070530  415892.0
# 7764  dangerous three son named devastating silas re...   360016   14167.0
#
# [5344 rows x 7 columns]

# %%
final_df.to_csv("source/final_comparison_df.csv")

# %%
final_df
# Out:
#                            title  vote_average release_date popularity  \
# 0                      Toy Story           7.7   1995-10-30  21.946943
# 1                        Jumanji           6.9   1995-12-15  17.015539
# 2                           Heat           7.7   1995-12-15  17.924927
# 3                      GoldenEye           6.6   1995-11-16  14.686036
# 4               Cutthroat Island           5.7   1995-12-22   7.284477
# ...                          ...           ...          ...        ...
# 7754  Frankenstein Created Woman           5.9   1967-03-15   2.302582
# 7755           Dawn of the Mummy           3.6   1981-12-11   0.283443
# 7756           The Pope Must Die           4.2   1991-06-21   9.015632
# 7758                     Opus II           6.7   1921-12-31   0.177238
# 7764             The Final Storm           3.7   2010-01-01   1.270832
#
#                                            bag_of_words   imdbId    tmdbId
# 0     jealousy woody toy afraid separate differences...   116985   88224.0
# 1     recluse giant insect discover magical inside t...    78763   42164.0
# 2     detective bank respects unstable notch robbery...    48028     220.0
# 3     unmask goldeneye prevent secret identity must ...   115851   23449.0
# 4     shaw must three skeptical exotic island raids ...   104691    9361.0
# ...                                                 ...      ...       ...
# 7754  hammer horror carries body responsible life to...    95631    9013.0
# 7755  craving group tomb revive curse years flesh sl...    58155   28667.0
# 7756  far vatican must priest named new qualified ol...  1087890   15952.0
# 7758  walter abstract animation ruttmann animation g...  6070530  415892.0
# 7764  dangerous three son named devastating silas re...   360016   14167.0
#
# [5344 rows x 7 columns]

# %%
final_df.iloc[0]['bag_of_words']
# Out:
# "jealousy woody toy afraid separate differences scene andy happily led duo plots toys lightyear place circumstances learns buzz boy heart brings birthday put friends live aside owner rivalry friendship new toy eventually losing room toy comes to life onto boy next door animation comedy family pixar animation studios united states of america tom hanks tim allen don rickles jim varney wallace shawn john ratzenberger annie potts john morris erik von detten laurie metcalf r. lee ermey sarah freeman penn jillette john lasseter joss whedon andrew stanton joel cohen alec sokolow bonnie arnold ed catmull ralph guggenheim steve jobs lee unkrich ralph eggleston robert gordon mary helen leasman kim blanchette marilyn mccoppen randy newman dale e. grahn robin cooper john lasseter pete docter joe ranft patsy bouge norm decarlo ash brannon randy newman roman figun don davis james flamberg mary beth smith rick mackay susan bradley william reeves randy newman andrew stanton pete docter gary rydstrom karen robert jackson chris montan rich quade michael berenstein colin brady davey crockett feiten angie glocka rex grignon tom k. gurney jimmy hayward hal t. hickel karen kiser anthony b. lamolinara guionne leroy bud luckey les major glenn mcqueen mark oftedal jeff pidgeon jeff pratt steve rabatich roger rose steve segal doug sheppeck alan sperling doug sweetland david tart ken willard thomas porter mark thomas henne oren jacob darwyn peachey mitch prater brian m. rosen sharon calahan galyn susman william cone shelley daniels lekven bob pauley bud luckey andrew stanton william cone steve johnson dan haskett tom holloway jean gillmore desirée mourad kelly o'connell sonoko konishi ann m. rockwell julie m. mcdonald robin lee tom freeman ada cochavi dana mulligan deirdre morrison lori lombardo ellen devine lauren beth strogoff gary rydstrom gary summers tim holland pat jackson tom myers j.r. grubbs susan sanford susan popovic dan engstrom ruth lambert mickie mcgowan toy story"
